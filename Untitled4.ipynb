# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinmayi-Bachu/Neural-Nomads/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
print("Class Weights:", weights)

model = RandomForestClassifier(class_weight='balanced', random_state=42)
model.fit(X_train, y_train)
# Out:
# Class Weights: [1.375      0.78571429]
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
import pandas as pd
import numpy as np

# Load your original Excel file
df = pd.read_excel("rtp_updated.xlsx")

# Add engineered features
np.random.seed(42)

df['Avg_Brightness'] = np.random.uniform(0.2, 0.9, size=len(df))        # Average brightness (scale 0-1)
df['Motion_Score'] = np.random.uniform(0.1, 1.0, size=len(df))          # Frame-to-frame motion
df['Speech_Ratio'] = np.random.uniform(0.0, 1.0, size=len(df))          # % of video with speech
df['FPS'] = np.random.choice([24, 30, 60], size=len(df))                # Frame rate
df['Keyword_Count'] = np.random.randint(0, 10, size=len(df))            # Detected unsafe words

# Save updated file
df.to_excel("rtp_updated_with_features.xlsx", index=False)
print("✅ File saved: rtp_updated_with_features.xlsx")
# Out:
# ✅ File saved: rtp_updated_with_features.xlsx

# %%
import pandas as pd
import numpy as np

# Load your Excel file, providing the full path if it's not in the current directory
# Using a relative path (assuming the file is in the same directory as the script)
file_path = "/rtp.xlsx"
# If the file is in a different directory, provide the full path. e.g. file_path = r"C:\Users\chinm\Downloads\rtp.xlsx"

df = pd.read_excel(file_path)

# Simulate NSFW object detection (0 = Safe, 1 = Unsafe)
np.random.seed(42)  # for reproducibility
df['NSFW_Object'] = np.random.randint(0, 2, size=len(df))

# Save updated dataset
df.to_excel("rtp_updated.xlsx", index=False)

# ... rest of your code ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# 1. Load the dataset
df = pd.read_excel("rtp_updated.xlsx")  # Make sure this file is in your working directory

# 2. Select features and label
features = ['Duration', 'NSFW_Object']  # Add more features if available
X = df[features]
y = df['Classification']

# 3. Encode labels (Safe = 0, Unsafe = 1)
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# 4. Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# 5. Train model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# 6. Predict and evaluate
y_pred = model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=le.classes_))
print("Accuracy:", accuracy_score(y_test, y_pred))

# 7. Predict on new data (example)
new_video = pd.DataFrame({
    'Duration': [45],  # in seconds
    'NSFW_Object': [1]  # 1 = detected
})
prediction = model.predict(new_video)
print("Prediction:", le.inverse_transform(prediction)[0])  # Outputs: Safe or Unsafe

# 8. Optional: Save the model
import joblib
joblib.dump(model, "video_safety_model.pkl")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         Safe       0.50      1.00      0.67         1
#       Unsafe       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3
#
# Accuracy: 0.6666666666666666
# Prediction: Safe
# ['video_safety_model.pkl']

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['auto', 'sqrt']
}

grid = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)

best_model = grid.best_estimator_
print("Best Params:", grid.best_params_)

# Evaluate
y_pred = best_model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=le.classes_))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Save the improved model
joblib.dump(best_model, "video_safety_model.pkl")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Best Params: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Classification Report:
#                precision    recall  f1-score   support
#
#         Safe       0.50      1.00      0.67         1
#       Unsafe       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3
#
# Accuracy: 0.6666666666666666
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 120 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# ...

# %%
import pandas as pd
import joblib

# Load trained model
model = joblib.load("video_safety_model.pkl")

# Set manually extracted features (duration, NSFW_Object)
duration = 210  # Example: from YouTube metadata
nsfw_flag = 0    # Simulate: 0 = no NSFW object detected

# Predict
df_test = pd.DataFrame({
    'Duration': [duration],
    'NSFW_Object': [nsfw_flag]
})
prediction = model.predict(df_test)

# Label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(["Safe", "Unsafe"])  # Make sure same order as training

print("Prediction:", le.inverse_transform(prediction)[0])
# Out:
# Prediction: Safe

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import joblib

# Load your training dataset
df = pd.read_excel("rtp_updated.xlsx")  # Make sure this file is available

# Features and label
X = df[['Duration', 'NSFW_Object']]
y = df['Classification']

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Train model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Save model and encoder
joblib.dump(model, "video_safety_model.pkl")
joblib.dump(label_encoder, "label_encoder.pkl")

print("✅ Model and LabelEncoder saved!")
# Out:
# ✅ Model and LabelEncoder saved!

# %%
# !pip install streamlit opencv-python joblib
# !streamlit run app.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.7 MB/s eta 0:00:00
# ...
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py

# %%
import streamlit as st
import pandas as pd
import cv2
import tempfile
import joblib
import os

# Load trained model and label encoder
model = joblib.load("video_safety_model.pkl")
label_encoder = joblib.load("label_encoder.pkl")

# App UI
st.title("🔍 Video Safety Classifier")
st.write("Upload a video and the model will classify it as **Safe** or **Unsafe**.")

# File uploader
uploaded_file = st.file_uploader("Upload a video file", type=["mp4", "mov", "avi", "mkv"])

if uploaded_file is not None:
    # Save the uploaded video temporarily
    with tempfile.NamedTemporaryFile(delete=False, suffix=".mp4") as tmp_file:
        tmp_file.write(uploaded_file.read())
        video_path = tmp_file.name

    st.video(video_path)

    # Extract video duration using OpenCV
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    duration = int(frame_count / fps) if fps else 0
    cap.release()

    st.write(f"🕒 Video Duration: {duration} seconds")

    # Simulate NSFW Object detection for now
    nsfw_detected = st.radio("Simulate NSFW content?", [0, 1], format_func=lambda x: "No NSFW" if x == 0 else "Contains NSFW")

    # Create feature input
    input_df = pd.DataFrame({
        "Duration": [duration],
        "NSFW_Object": [nsfw_detected]
    })

    # Predict with model
    prediction = model.predict(input_df)
    prediction_label = label_encoder.inverse_transform(prediction)[0]

    # Output result
    st.success(f"✅ Prediction: **{prediction_label}**")

    # Clean up temp file
    os.remove(video_path)
# Out:
# 2025-04-20 13:15:07.548 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-20 13:15:07.763
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-04-20 13:15:07.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-20 13:15:07.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-20 13:15:07.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-20 13:15:07.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-20 13:15:07.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
